# %% [markdown]
# Assignment 2: Lunar Lander
#
# Task 4
#
# Student Name - Sandeep Dubey
# Student Name - Kshitija Shelar
#
# Student Number - 20200220
# Student Number - 20200155

# %% [markdown]
# ### Analysis of Task 1

# %% [markdown]
# Before undersampling

# %% [markdown]
# 1. we can see that the classes are imbalanced!!
#
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# After undersampling

# %% [markdown]
# 1. classes are not imbalanced anymore!
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# LeNet-5 is a convolutional neural network architecture and is one of the simplest architectures. It consists of 2 convolutional and 3 fully-connected layers (therefore, “5” — as it is very common for the names of neural networks to be derived from the number of convolutional and fully connected layers that they consist). The average-pooling layer as we know it now was called a sub-sampling layer and it had trainable weights (which isn’t the current practice of designing CNNs nowadays). This architecture has about 60,000 parameters.

# %% [markdown]
# We can see that LENET-5 is giving us the maximum accuracy and F1-Score on training data as 81.1 and 65% respectively. The accuracy on test data is 63.02%.
#
#
# The model parameters were as follows:
# LENET-5
# 1. batch_size = 128
# 2. epochs = 50
# 3. loss='binary_crossentropy'
# 4. optimizer='rmsprop'
# 5. ROWS = 162 it means that this would be the Target image width, after resizing and reshaping input image
# 6. COLS = 128 it means that this would be the  Target image height, after resizing and reshaping input image
# 7. CHANNELS = 1  We are only taking single channel as an input to our network. We will shrink 3 channeled input to single channel.
# 8. sample_rate=0.3  Sampling rate is %of data we are sampling from total number of images. In our model, we have used 10% o data.
# 9. input_shape=(ROWS, COLS,CHANNELS)  For lenet input shape is (162,128,1).
# 10. labelencoder - we have used label encoder to encode categorical features
#
# The reason we are getting high accuracy is that the classes are imbalanced. For balancing the classes we used under-sampling.
#
# Model parameters are as follows: RandomUnderSampler
#
# 1. batch_size = 64
# 2. epochs = 50
# 3. loss='binary_crossentropy'
# 4. optimizer='rmsprop'
# 5. ROWS = 162 it means that this would be the Target image width, after resizing and reshaping input image
# 6. COLS = 128 it means that this would be the  Target image height, after resizing and reshaping input image
# 7. CHANNELS = 1  We are only taking single channel as an input to our network. We will shrink 3 channeled input to single channel.
# 8. sample_rate=0.3  Sampling rate is %of data we are sampling from total number of images. In our model, we have used 10% o data.
# 9. input_shape=(ROWS, COLS,CHANNELS)  For lenet input shape is (162,128,1).

# %% [markdown]
# #### The results obtained after both model's execution is as follows:

# %% [markdown]
# ### LENET Performance comparision
# 1. Lenet accuracy on training set accuracy: 81.11%
# 2. Lenet accuracy on test set 0.6302367941712204
# Lenet classfication report
#                 precision    recall  f1-score   support
#
#            0       0.62      0.68      0.65       253
#            1       0.50      0.13      0.21        15
#            2       0.65      0.64      0.65       266
#            3       0.17      0.07      0.10        15
#     accuracy                           0.63       549
#
#     macro avg       0.49      0.38      0.40       549
#
#     weighted avg       0.62      0.63      0.62       549

# %% [markdown]
# ### LENET performance comparision after undersampling
# 1. Lenet accuracy on training set after undersampling accuracy: 86.42%
# 2. Lenet accuracy on test set after undersampling    0.5142857142857142
#
# Lenet classfication report after undersampling
#
#               precision    recall  f1-score   support
#
#            0       0.36      0.71      0.48         7
#            1       0.60      0.38      0.46         8
#            2       0.70      0.64      0.67        11
#            3       0.50      0.33      0.40         9
#
#     accuracy                           0.51        35
#    macro avg       0.54      0.51      0.50        35
# weighted avg       0.56      0.51      0.51        35

# %% [markdown]
# #### VGG16 is a convolution neural network which is 16 layers deep and hence the "16" in the name.
#
# As this model was computationally very heavy and was taking a huge amount of time, we just tested .01% of the data on and and hence the results are not  very reliable or good.

# %% [markdown]
# VGG 16 model parameters:
# 1. batch_size = 128
# 2. epochs = 50
# 3. sample_rate=0.01
# 4. loss=sparse_categorical_crossentropy
# 5. optimizer='sgd'
# 6. ROWS = 224
# 7. COLS = 224
# 8. CHANNELS = 3
#
# Model arguments
#
# include_top: whether to include the 3 fully-connected layers at the top of the network.
# weights: one of None (random initialization), 'imagenet' (pre-training on ImageNet), or the path to the weights file to be loaded.
# input_tensor: optional Keras tensor (i.e. output of layers.Input()) to use as image input for the model.
# input_shape: optional shape tuple, only to be specified if include_top is False (otherwise the input shape has to be (224, 224, 3) (with channels_last data format) or (3, 224, 224) (with channels_first data format). It should have exactly 3 input channels, and width and height should be no smaller than 32. E.g. (200, 200, 3) would be one valid value.
# pooling: Optional pooling mode for feature extraction when include_top is False. - None means that the output of the model will be the 4D tensor output of the last convolutional block. - avg means that global average pooling will be applied to the output of the last convolutional block, and thus the output of the model will be a 2D tensor. - max means that global max pooling will be applied.
# classes: optional number of classes to classify images into, only to be specified if include_top is True, and if no weights argument is specified.
# classifier_activation: A str or callable. The activation function to use on the "top" layer.

# %% [markdown]
# Accuracy: 0.47368421052631576
#
#               precision    recall  f1-score   support
#
#            0       0.47      1.00      0.64         9
#            1       0.00      0.00      0.00        10
#
#     accuracy                           0.47        19
#     macro avg       0.24      0.50      0.32        19
#     weighted avg       0.22      0.47      0.30        19

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### Task 2 and Task 3

# %% [markdown]
# Model1
#
# 1) We built a sequential model with three hidden layers, each containing 16 neurons. The input will be a 1 x state space vector, and each potential action will have an output neuron that predicts the Q value of that action for each move. We can select the action with the highest Q value by taking the argmax of the outputs.
#
# 2) We've built a SequentialMemory object with the rl.memory class. SequentialMemory is a form of memory that is organized in a sequential order. This creates a data structure for storing the agent's experience that is both quick and effective. We've set the maximum size of this memory object to 50000 in that. As new memories are added to this memory, it fills up, and old ones fade away.
#
# 3).We used EpsGreedyQPolicy to strike a balance between discovery and exploitation. In this policy, we can change the value of. If a random number less than this value is chosen, an event is chosen entirely at random. Otherwise, the best course of action is selected. This phase allows for some haphazard discovery of the worth of different actions in various states, and it can be scaled back over time to allow the algorithm to focus more on leveraging the best strategies it has discovered. We used the default value of eps, which is 0.1, in this model.
#
# 4) After our model,memory and policy are defined, we create a deep Q network Agent and send that agent with those objects.
#
# 5) Finally the model is compiled using a mean-squared error loss function with the Adam optimizer. The learning rate of Adam optimizer is set to 0.0001.

# %% [markdown]
# We are training model 1 with eps value of 0.2 and learning rate of 0.0001 having greedypolicy. We are testing it for 50 episodes, model1 gives a mean reward of -155 with standard deviation of 54.89. Which shows that the rewards do not vary a lot from mean, also the min and max value of reward ranges from -265 to 2 hence showing some outer range values. Also the time taken is 436.

# %% [markdown]
# 50 episodes

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Model 2
#
# used DQN agent with EPSgreedypolicy with eps of 0.1, trained using mean absolute error as loss with the learning rate of 0.001
#
# We are training model 2 with eps value of 0.1 and learning rate of 0.001 having greedypolicy. We are testing it for 50 episodes, model2 gives a mean reward of -846 with standard deviation of 336.65. Which shows that the rewards vary a lot from mean, also the min and max value of reward ranges from -1180 to 81.78 hence showing some extreme outer range values. Also the time taken is 418 for 189 episode while training which shows model2 takes more time then model 1 to run.
#
#
# Test rewards (#episodes=50): mean=-846.67, std=336.65, min=-1180.95, max=-81.78

# %% [markdown]
# 50 episodes

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Task 3
#
#
# In task 3 We are testing model 1 with eps =0.2 and learning rate of 0.0001 for 200 episodes, model1 gives a mean reward of -213.46 with standard deviation of 83.45. Which shows that the rewards do not vary a lot from mean, also the min and max value of reward ranges from -433 to 15.75 hence showing some outer range values. Although testing on 200 episodes rewards have become less and standard deviation has increased but still it perform well as compared to model 2

# %% [markdown]
# 200 episodes

# %% [markdown]
# Test rewards (#episodes=200): mean=-213.46, std=83.45, min=-433.72, max=15.75

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# *In task 3 We are testing model 2 with eps =0.1 and learning rate of 0.001 for 200 episodes, model2 gives a mean=-868.55, std=336.97, min=-1314.64, max=13.80. Which shows that the rewards do vary a lot from mean,although for 50 episodes and 200 episodes the mean is same but the min and max value of reward ranges from -1314 to 13.80 hence showing some outer range values. Although testing on 200 episodes rewards are similar to 50 episodes and standard deviation has increased *

# %% [markdown]
# 200 episodes

# %% [markdown]
# Test rewards (#episodes=200): mean=-868.55, std=336.97, min=-1314.64, max=13.80

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Summary for Task 2 and Task 3
#
#
# 1) Learning rate is used to control the weights adjustments in the network with respect to the gradient loss. If the value of learning rate is small, it would mean more time along the slope to reach the local minima. If the rate is too high, we might miss the local minima by overshooting. From the results we can see that Model 1 is giving better rewards than model 2 which has eps 0.2 and learning rate of 0.0001.
#
# 2) One more observation is that the computation time increases as the learning rate increases. For example, the time needed for models with learning rate 0.001 is higher than with the models which has the learning rate as 0.0001.
#
# 3) Esp Greedy Q policy is used to balance out the exploration vs exploitation problem. From the discussion above we can see that for learning rate 0.0001, eps=0.1 is giving the better result. however, for learning rate 0.001, eps=0.2 is giving the better results. Hence, we can conclude that learning rate and epsilon value has a certain impact on the model’s performance.
#
# What all these points means is that initially when the agent is new to the environment it will try to explore around a lot and may earn a lot of negative rewards or even positive rewards. However, as the agent becomes more familiar with the environment, it starts to learn about the environment and tried to take the action with best possible reward from the exploration before.

# %% [markdown]
# Conclusion
#
# To conclude, we can see from the observations that DQN performs better compared to the rest. DQN is comparatively easy to train. As labelled data is required for supervised learning, sometimes it may happen that we find it difficult to get so much of labelled data. In reinforcement, we try to optimize the rewards the aim is to maximize the rewards. Lastly, using the right values for the hyper parameters is very crucial to determine the performance of the model.
